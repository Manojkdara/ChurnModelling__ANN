# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojkdara/ChurnModelling__ANN/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shrutimechlearn/churn-modelling")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'churn-modelling' dataset.
# Path to dataset files: /kaggle/input/churn-modelling

# %%
import pandas as pd
import os
from sklearn.preprocessing import OneHotEncoder

file_name = 'Churn_Modelling.csv'
full_path = os.path.join(path, file_name)


df = pd.read_csv(full_path)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df= df.drop(df.columns[:3],axis=1)
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
print(categorical_columns)
# Out:
# ['Geography', 'Gender']

# %%
geography=pd.get_dummies(df["Geography"],drop_first=True,dtype=int)
gender=pd.get_dummies(df['Gender'],drop_first=True,dtype=int)

# %%
df =df.drop(["Geography","Gender"],axis=1)
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited
# 0                  1        101348.88       1
# 1                  1        112542.58       0
# 2                  0        113931.57       1
# 3                  0         93826.63       0
# 4                  1         79084.10       0
# ...              ...              ...     ...
# 9995               0         96270.64       0
# 9996               1        101699.77       0
# 9997               1         42085.58       1
# 9998               0         92888.52       1
# 9999               0         38190.78       0
#
# [10000 rows x 9 columns]

# %%
X= df.iloc[:, 0:-1]
y=df.iloc[:,-1]

# %%
X=pd.concat([X,geography,gender],axis=1)
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# 1                  1        112542.58        0      1     0
# 2                  0        113931.57        0      0     0
# 3                  0         93826.63        0      0     0
# 4                  1         79084.10        0      1     0
# ...              ...              ...      ...    ...   ...
# 9995               0         96270.64        0      0     1
# 9996               1        101699.77        0      0     1
# 9997               1         42085.58        0      0     0
# 9998               0         92888.52        1      0     1
# 9999               0         38190.78        0      0     0
#
# [10000 rows x 11 columns]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %% [markdown]
# **ANN**

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
# from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()
model.add(Dense(units=6, activation='relu', input_dim=11))
model.add(Dense(units=6, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))


callback = keras.callbacks.EarlyStopping(monitor='val_loss',patience=3)


model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=10, validation_split=0.33,callbacks=callback)
# Out:
# Epoch 1/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.7425 - loss: 0.5699 - val_accuracy: 0.7955 - val_loss: 0.4739
# Epoch 2/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7882 - loss: 0.4774 - val_accuracy: 0.7955 - val_loss: 0.4463
# Epoch 3/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7984 - loss: 0.4387 - val_accuracy: 0.7955 - val_loss: 0.4345
# Epoch 4/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7900 - loss: 0.4345 - val_accuracy: 0.7955 - val_loss: 0.4286
# Epoch 5/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8007 - loss: 0.4195 - val_accuracy: 0.8103 - val_loss: 0.4245
# Epoch 6/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8177 - loss: 0.4168 - val_accuracy: 0.8175 - val_loss: 0.4204
# Epoch 7/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8302 - loss: 0.4131 - val_accuracy: 0.8175 - val_loss: 0.4173
# Epoch 8/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8357 - loss: 0.4022 - val_accuracy: 0.8224 - val_loss: 0.4123
# Epoch 9/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8258 - loss: 0.4094 - val_accuracy: 0.8228 - val_loss: 0.4067
# Epoch 10/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8363 - loss: 0.3924 - val_accuracy: 0.8270 - val_loss: 0.4020
# Epoch 11/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8396 - loss: 0.3860 - val_accuracy: 0.8323 - val_loss: 0.3949
# Epoch 12/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8406 - loss: 0.3798 - val_accuracy: 0.8345 - val_loss: 0.3921
# Epoch 13/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8440 - loss: 0.3832 - val_accuracy: 0.8330 - val_loss: 0.3869
# Epoch 14/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8442 - loss: 0.3710 - val_accuracy: 0.8376 - val_loss: 0.3832
# Epoch 15/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8366 - loss: 0.3800 - val_accuracy: 0.8413 - val_loss: 0.3802
# Epoch 16/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8525 - loss: 0.3581 - val_accuracy: 0.8455 - val_loss: 0.3766
# Epoch 17/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8515 - loss: 0.3517 - val_accuracy: 0.8455 - val_loss: 0.3743
# Epoch 18/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8546 - loss: 0.3588 - val_accuracy: 0.8451 - val_loss: 0.3732
# Epoch 19/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8514 - loss: 0.3557 - val_accuracy: 0.8463 - val_loss: 0.3718
# Epoch 20/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8535 - loss: 0.3575 - val_accuracy: 0.8504 - val_loss: 0.3661
# Epoch 21/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8560 - loss: 0.3557 - val_accuracy: 0.8504 - val_loss: 0.3660
# Epoch 22/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8661 - loss: 0.3420 - val_accuracy: 0.8508 - val_loss: 0.3635
# Epoch 23/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8652 - loss: 0.3277 - val_accuracy: 0.8493 - val_loss: 0.3641
# Epoch 24/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8592 - loss: 0.3359 - val_accuracy: 0.8501 - val_loss: 0.3616
# Epoch 25/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8636 - loss: 0.3436 - val_accuracy: 0.8550 - val_loss: 0.3612
# Epoch 26/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8541 - loss: 0.3473 - val_accuracy: 0.8493 - val_loss: 0.3605
# Epoch 27/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8673 - loss: 0.3283 - val_accuracy: 0.8546 - val_loss: 0.3600
# Epoch 28/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8609 - loss: 0.3374 - val_accuracy: 0.8531 - val_loss: 0.3582
# Epoch 29/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8654 - loss: 0.3299 - val_accuracy: 0.8493 - val_loss: 0.3597
# Epoch 30/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8692 - loss: 0.3230 - val_accuracy: 0.8561 - val_loss: 0.3601
# Epoch 31/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8696 - loss: 0.3236 - val_accuracy: 0.8482 - val_loss: 0.3608

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", acc)
print("Test Loss:", loss)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8638 - loss: 0.3317
# Test Accuracy: 0.8634999990463257
# Test Loss: 0.3409138023853302

# %%
import matplotlib.pyplot as plt


print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Predicting the Test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score
print("Accuracy:",accuracy_score(y_pred,y_test))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8635
# [[1533   62]
#  [ 211  194]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1595
#            1       0.76      0.48      0.59       405
#
#     accuracy                           0.86      2000
#    macro avg       0.82      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
